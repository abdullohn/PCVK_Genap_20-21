# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullohn/PCVK_Genap_20-21/blob/main/week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as pl
import numpy as np
import PIL
import io
import html
import time
# %matplotlib inline
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode

# %%
cascade_wajah=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

kante_asli = cv2.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kante.jpeg')
kante_detect = cv2.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kante.jpeg')
wajah1 = cascade_wajah.detectMultiScale(kante_detect)

wajah = cascade_wajah.detectMultiScale(kante_asli)
for (x,y,w,h) in wajah: 
 cv2.rectangle(kante_asli,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv2.cvtColor(kante_detect, cv2.COLOR_BGR2RGB))
axarr[0].imshow(cv2.cvtColor(kante_detect, cv2.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv2.cvtColor(kante_asli, cv2.COLOR_BGR2RGB))
axarr[1].imshow(cv2.cvtColor(kante_asli, cv2.COLOR_BGR2RGB))
plt.show()

# %%
cascade_wajah=cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalface_default.xml")


kartini = cv.imread ('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kartini.jpg')
kartini_1 = cv.imread ('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kartini.jpg')
wajah1 = cascade_wajah.detectMultiScale(kartini_1)  
wajah = cascade_wajah.detectMultiScale(kartini) 

for (x,y,w,h) in wajah:
 cv.rectangle(kartini,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,5)) 

f, axarr = plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(cv.cvtColor(kartini_1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(kartini_1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
plt.show()

# %%
kucing = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kucing.jpg')
kucing1 = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kucing.jpg')
kucing_awal = cv.cvtColor(kucing, cv.COLOR_BGR2GRAY)
kucing_kemudian = cv.cvtColor(kucing1, cv.COLOR_BGR2GRAY)

wajah = cascade_wajah.detectMultiScale(kucing)
for (x,y,w,h) in wajah:
 cv.rectangle(kucing1,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,5))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kucing_awal, cmap='gray')
plt.subplot(122),plt.imshow(kucing_kemudian, cmap='gray')
plt.show()

# %%
cascade_wajah=cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalface_default.xml")

mask = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/mask.png',0)
mask1 = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/mask.png',0)

wajah = cascade_wajah.detectMultiScale(mask1)
for (x,y,w,h) in wajah:
   cv.rectangle(mask1,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (15,5))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(mask, cmap='gray')
plt.subplot(122),plt.imshow(mask1, cmap='gray')
plt.show()

# %%
jordan = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/mjordan.jpg',0)
jordan1 = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/mjordan.jpg',0)

wajah = cascade_wajah.detectMultiScale(jordan1)
for (x,y,w,h) in wajah:
 cv.rectangle(jordan1,(x,y),(x+w,y+h),(255,0,0),3)
plt.figure(figsize = (10,5))

f, axarr = plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(jordan, cmap='gray')
plt.subplot(122),plt.imshow(jordan1, cmap='gray')
plt.show()

# %%
kelompok = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/solvayconf.jpg',0)
kelompok1 = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/solvayconf.jpg',0)

wajah = cascade_wajah.detectMultiScale(kelompok1)
for (x,y,w,h) in wajah:
 cv.rectangle(kelompok1,(x,y),(x+w,y+h),(0,255,0),3)

plt.figure(figsize = (10,5))
f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kelompok, cmap='gray')
plt.subplot(122),plt.imshow(kelompok1, cmap='gray')
plt.show()

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK-GENAP-2021/haarcascades/haarcascade_frontalcatface.xml')

kucing = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kucing.jpg',0)
kucing1 = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kucing.jpg',0)

wajah = cascade_wajah.detectMultiScale(kucing1)
for (x,y,w,h) in wajah:
 cv.rectangle(kucing1,(x,y),(x+w,y+h),(0,255,0),3)

plt.figure(figsize = (10,10))
f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kucing, cmap='gray')
plt.subplot(122),plt.imshow(kucing1, cmap='gray')
plt.show()

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK-GENAP-2021/haarcascades/haarcascade_righteye_2splits.xml')

kante = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kante.jpeg')
kante_awal = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/kante.jpeg')
kante_gray = cv.cvtColor(kante, cv.COLOR_BGR2GRAY)
kante_kemudian = cv.cvtColor(kante_awal, cv.COLOR_BGR2GRAY)

wajah = cascade_wajah.detectMultiScale(kante_gray)
for (x,y,w,h) in wajah:
 cv.rectangle(kante_gray,(x,y),(x+w,y+h),(255,0,0),3)

# Plot outputs
f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kante_kemudian, cmap='gray')
plt.subplot(122),plt.imshow(kante_gray, cmap='gray')
plt.show()

# %%
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import PIL
import io
import html
import time

# %%
def js_to_image(js_reply):
  image_bytes = b64decode(js_reply.split(',')[1])
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img


def bbox_to_bytes(bbox_array):
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  bbox_PIL.save(iobuf, format='png')
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64decode(iobuf.getvalue()), 'utf-8')))
  
  return bbox_to_bytes

# %%
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
  def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
      async function takePhoto(quality){
        const div = document.createElement('div');
        const capture = document.createElement('button');
        capture.textContent = 'Capture';
        div.appendChild(capture);

        const video = document.createElement('video');
        video.style.display = 'block';
        const stream = await navigator.mediaDevices.getUserMedia({video: true});

        document.body.appendChild(div);
        div.appendChild(video);
        video.srcObject = stream;
        await video.play();

        google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

        await new Promise((resolve) => capture.onclick = resolve);

        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);
        stream.getVideoTracks()[0].stop();
        div.remove();
        return canvas.toDataURL('image/jpeg', quality);
      }
      ''')
    display(js)

    data = eval_js('takePhoto({})'.format(quality))
    img = js_to_image(data)
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    print(gray.shape)
    faces = face_cascade.detectMultiScale(gray)
    for(x,y,w,h) in faces:
      img = cv2.rectangle(img,(x,y),(x+w,y+h),(255, 0, 0),2)

    cv2.imwrite(filename, img)

    return filename

# %%
image = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/facedet/mjordan.jpg') # reads the image
image = cv.cvtColor(image, cv.COLOR_BGR2GRAY) # convert to GRAY

figure_size = 9 # the dimension of the x and y axis of the kernal.
new_image = cv.medianBlur(image, figure_size)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter')
plt.show()
