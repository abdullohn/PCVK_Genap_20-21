# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullohn/PCVK_Genap_20-21/blob/main/week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/female.tiff')
plt.imshow(img)

# %%
print('Mengubah Kontras dan Tingkat Kecerahan Citra')
print('--------------------------------')
try:
  brightness = int(input('Masukan nilai kecerahan: '))
except ValueError:
  print('Error')

original = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c]+ brightness,0,255)

final_frame = cv.hconcat((original,brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukan nilai kecerahan: 50
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F25EE80BC90>

# %%
print('Mengubah Kontras dan Tingkat Kecerahan Citra')
print('--------------------------------')
try:
  brightness = int(input('Masukan nilai kecerahan[-255 - 255]: '))
  contrast = float(input('Masukkan kontras [1.0 - 3.0]: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c]+ brightness,0,255)

final_frame = cv.hconcat((original,brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah Kontras dan Tingkat Kecerahan Citra
# --------------------------------
# Masukan nilai kecerahan[-255 - 255]: 60
# Masukkan kontras [1.0 - 3.0]: 1.5
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F25EDE321D0>

# %%
print('Mengubah kontras dan tingkat kecerahan citra dengan Transformasi Log')
print('--------------------------------------------------------------------')
try:
  brightness = int(input('Masukan nilai kecerahan: '))
except ValueError:
  print('Error')

original = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(brightness*(np.log(1+original[y,x,c])),0,255)

final_frame = cv.hconcat((original,brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah kontras dan tingkat kecerahan citra dengan Transformasi Log
# --------------------------------------------------------------------
# Masukan nilai kecerahan: 40
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F25EDE32510>

# %%
print('Averaging')
print('--------------------------------------------------------------------')


original = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/mandrill.tiff')
original = cv.cvtColor(original,cv.COLOR_BGR2RGB)

gray = cv.imread('/content/drive/MyDrive/PCVK-GENAP-2021/mandrill.tiff')
gray = cv.cvtColor(gray,cv.COLOR_BGR2RGB)

R, G, B = original[:,:,0], original[:,:,1], original[:,:,2]
average = (R+G+B)/3

gray[:,:,0] = average
gray[:,:,1] = average
gray[:,:,2] = average

fig, axs = plt.subplots(1, 2)

axs[0].imshow(original)
axs[1].imshow(gray)
# Out:
# Averaging
# --------------------------------------------------------------------
